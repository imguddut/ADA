# %%
import matplotlib.pyplot as plt

# %%
sizes = [1000 * i for i in range(1, 26)]

# %%
# Bubble Sort Times
bubble_sort_times = [
    0.0018116, 0.0069998, 0.0157012, 0.0274998, 0.0421526, 0.0669013, 0.0923285, 
    0.123854, 0.157314, 0.196518, 0.248374, 0.289536, 0.339975, 0.468719, 0.587601, 
    0.542667, 0.623651, 0.717061, 0.808046, 0.920157, 1.00713, 1.10333, 1.18236, 
    1.34282, 1.4999
]

# Selection Sort Times
selection_sort_times = [
    0.0005, 0.0018002, 0.0037997, 0.0071997, 0.0102998, 0.0150998, 0.0198016, 
    0.0252047, 0.0349018, 0.0405923, 0.0491999, 0.0580203, 0.0678998, 0.0791013, 
    0.09, 0.102272, 0.113376, 0.127101, 0.141823, 0.15601, 0.17213, 0.188478, 
    0.206142, 0.222723, 0.243842
]

# Insertion Sort Times
insertion_sort_times = [
    0.9994, 4.1001, 9.3, 16.3001, 25.6998, 36.9511, 49.3338, 63.6016, 75.0206, 
    92.3411, 111.249, 132.6, 156.376, 181.088, 207.89, 235.17, 267.615, 306.09, 
    339.211, 388.556, 421.657, 463.317, 494.319, 602.871, 1196.3
]

# Iterative QuickSort Times
iterative_quicksort_times = [
    0.0002111, 0.0003996, 0.0004014, 0.0004997, 0.0007024, 0.0007017, 0.0008108, 
    0.0011047, 0.0011002, 0.0015001, 0.0012001, 0.0015997, 0.0014907, 0.0016996, 
    0.0021998, 0.0020989, 0.0022985, 0.0025001, 0.0026002, 0.003899, 0.0026023, 
    0.0027001, 0.0029002, 0.0032998, 0.0037001
]

merge_sort = [9.99e-005, 0.0001998, 0.0003016, 0.0001993, 0.0004999, 0.0007017, 0.0005988, 0.000798, 0.0010002, 0.0009883, 0.0010998, 0.0012998, 0.0015998, 0.0015003, 0.0014007, 0.0018, 0.0020015, 0.0019001, 0.0020997, 0.0024002, 0.0025997, 0.0027016, 0.0027997, 0.0027032, 0.0029996]
quicksort = [9.99e-005, 0.0001997, 0.0002999, 0.0002, 0.0004019, 0.0004999, 0.0006019, 0.0005999, 0.0006999, 0.0010017, 0.0009979, 0.0011002, 0.0013015, 0.0014006, 0.0012001, 0.0015001, 0.0015964, 0.0016, 0.0017998, 0.0020978, 0.0017018, 0.0021015, 0.0020999, 0.0023031, 0.002498]

# %%
# Plot Bubble Sort
plt.figure(figsize=(5, 3))
plt.plot(sizes, bubble_sort_times, label='Bubble Sort', marker='o')
plt.xlabel('Input Size')
plt.ylabel('Time (seconds)')
plt.title('Bubble Sort Performance')
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Selection Sort
plt.figure(figsize=(5, 3))
plt.plot(sizes, selection_sort_times, label='Selection Sort', marker='s', color='red')
plt.xlabel('Input Size')
plt.ylabel('Time (seconds)')
plt.title('Selection Sort Performance')
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Insertion Sort
plt.figure(figsize=(5, 3))
plt.plot(sizes, insertion_sort_times, label='Insertion Sort', marker='^', color='green')
plt.xlabel('Input Size')
plt.ylabel('Time (seconds)')
plt.title('Insertion Sort Performance')
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Iterative QuickSort
plt.figure(figsize=(5, 3))
plt.plot(sizes, iterative_quicksort_times, label='Iterative QuickSort', marker='d', color='purple')
plt.xlabel('Input Size')
plt.ylabel('Time (seconds)')
plt.title('Iterative QuickSort Performance')
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Iterative QuickSort
plt.figure(figsize=(5, 3))
plt.plot(sizes, merge_sort, label='Mergesort', marker='d', color='yellow')
plt.xlabel('Input Size')
plt.ylabel('Time (seconds)')
plt.title('Iterative QuickSort Performance')
plt.legend()
plt.grid()
plt.show()

# %%
# Plot Iterative QuickSort
plt.figure(figsize=(5, 3
                ))
plt.plot(sizes, quicksort, label='QuickSort', marker='d', color='purple')
plt.xlabel('Input Size')
plt.ylabel('Time (seconds)')
plt.title('Iterative QuickSort Performance')
plt.legend()
plt.grid()
plt.show()
